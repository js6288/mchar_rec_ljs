# %%
import os
from glob import glob
import torch
from PIL import Image
import torch.nn as nn
from scipy.cluster.hierarchy import weighted
from tqdm.auto import tqdm
from torchvision import transforms
from torchvision.utils import save_image, make_grid
from torch.optim import SGD, Adam
from torch.optim.lr_scheduler import CosineAnnealingWarmRestarts, MultiStepLR
from torch.utils.data import DataLoader, Dataset, WeightedRandomSampler
import pandas as pd
import numpy as np
import torch.nn.functional as F
import json
from torchvision.models.mobilenet import mobilenet_v2, MobileNet_V2_Weights
from torchvision.models.resnet import resnet50, resnet18, resnet101, ResNet18_Weights, ResNet50_Weights, \
    ResNet101_Weights
from torchsummary import summary
import random
from code.DigitsDataset import DigitsDataset
from code.jessie_utils import data_dir
from code.Config import Config

print("load config:")
print("batch_size: ", Config.batch_size)
print("start_epoch", Config.start_epoch)
# Out:
# load config:
# batch_size:  64
# start_epoch 0

# %%
#超参数设定 （注释：定义在独立文件中）
# class Config:
# ....


config = Config()

# %%
# # 定义数据 , Windows 可能会导致一些错误，需要将它封装在单独的文件中
# class DigitsDataset(Dataset):
#     """
#
#     DigitsDataset
#
#     Params:
#       data_dir(string): data directory
#
#       label_path(string): label path
#
#       aug(bool): wheather do image augmentation, default: True
#     """

# %%
# 自定义网络
# 以ResNet50 为主干网络
class DigitsResNet101(nn.Module):
    def __init__(self):
        super(DigitsResNet101, self).__init__()
        self.net = resnet101(weights=ResNet101_Weights.IMAGENET1K_V2)

        self.net = nn.Sequential(*list(self.net.children())[:-1])
        self.cnn = self.net

        # 定义4个隐藏全连接层（每个对应一个字符位置）
        self.hd_fc1 = nn.Linear(2048, 128)
        self.hd_fc2 = nn.Linear(2048, 128)
        self.hd_fc3 = nn.Linear(2048, 128)
        self.hd_fc4 = nn.Linear(2048, 128)

        # Dropout层防止过拟合
        self.dropout_1 = nn.Dropout(0.25)
        self.dropout_2 = nn.Dropout(0.25)
        self.dropout_3 = nn.Dropout(0.25)
        self.dropout_4 = nn.Dropout(0.25)

        # 最终分类层（每个位置输出11类：0-9数字 + 空白符）
        self.fc1 = nn.Linear(128, config.class_num)
        self.fc2 = nn.Linear(128, config.class_num)
        self.fc3 = nn.Linear(128, config.class_num)
        self.fc4 = nn.Linear(128, config.class_num)

    def forward(self, img):
        feat = self.cnn(img)
        feat = feat.view(feat.shape[0], -1)  #展平

        # 多任务分支（4个独立分类器）
        feat1 = self.dropout_1(self.hd_fc1(feat))  #降维+dropout
        feat2 = self.dropout_2(self.hd_fc2(feat))
        feat3 = self.dropout_3(self.hd_fc3(feat))
        feat4 = self.dropout_4(self.hd_fc4(feat))

        # 分类输出（4个位置的预测结果）
        c1 = self.fc1(feat1)  # 每个输出形状: (batch, 11)
        c2 = self.fc2(feat2)
        c3 = self.fc3(feat3)
        c4 = self.fc4(feat4)

        return c1, c2, c3, c4


class DigitsResNet50(nn.Module):
    def __init__(self):
        super().__init__()

        #resnet50
        #self.net = resnet50(pretrained=True)  # deprecated
        self.net = resnet50(weights=ResNet50_Weights.IMAGENET1K_V1)
        self.avgpool = nn.AdaptiveAvgPool2d(1)
        # 移除原始ResNet50的最后全连接层，保留特征提取层
        # children()[:-1] 表示取除最后一层外的所有层
        self.net = nn.Sequential(*list(self.net.children())[:-1])
        self.cnn = self.net

        # 定义4个隐藏全连接层（每个对应一个字符位置）
        self.hd_fc1 = nn.Linear(2048, 128)
        self.hd_fc2 = nn.Linear(2048, 128)
        self.hd_fc3 = nn.Linear(2048, 128)
        self.hd_fc4 = nn.Linear(2048, 128)

        # Dropout层防止过拟合
        self.dropout_1 = nn.Dropout(0.25)
        self.dropout_2 = nn.Dropout(0.25)
        self.dropout_3 = nn.Dropout(0.25)
        self.dropout_4 = nn.Dropout(0.25)
        # 最终分类层（每个位置输出11类：0-9数字 + 空白符）
        self.fc1 = nn.Linear(128, config.class_num)
        self.fc2 = nn.Linear(128, config.class_num)
        self.fc3 = nn.Linear(128, config.class_num)
        self.fc4 = nn.Linear(128, config.class_num)

    def forward(self, img):
        feat = self.cnn(img)
        feat = feat.view(feat.shape[0], -1)  #展平

        # 多任务分支（4个独立分类器）
        feat1 = self.dropout_1(self.hd_fc1(feat))  #降维+dropout
        feat2 = self.dropout_2(self.hd_fc2(feat))
        feat3 = self.dropout_3(self.hd_fc3(feat))
        feat4 = self.dropout_4(self.hd_fc4(feat))

        # 分类输出（4个位置的预测结果）
        c1 = self.fc1(feat1)  # 每个输出形状: (batch, 11)
        c2 = self.fc2(feat2)
        c3 = self.fc3(feat3)
        c4 = self.fc4(feat4)

        return c1, c2, c3, c4


class DigitsResNet18(nn.Module):
    def __init__(self):
        super().__init__()

        #resNet18
        self.net = resnet18(weights=ResNet18_Weights.IMAGENET1K_V1)
        # 移除原始全连接层（fc），替换为Identity层（即无操作）
        self.net.fc = nn.Identity()
        # 定义BatchNorm层
        self.bn = nn.BatchNorm1d(512)

        # 四个独立连接层
        self.fc1 = nn.Linear(512, config.class_num)
        self.fc2 = nn.Linear(512, config.class_num)
        self.fc3 = nn.Linear(512, config.class_num)
        self.fc4 = nn.Linear(512, config.class_num)

    def forward(self, img):
        # feature = self.net(img).squeeze()
        features = self.net(img)
        features = features.view(features.shape[0], -1)
        features = self.bn(features)  #添加BatchNorm

        fc1 = self.fc1(features)
        fc2 = self.fc2(features)
        fc3 = self.fc3(features)
        fc4 = self.fc4(features)

        return fc1, fc2, fc3, fc4


# modelNet_V2为主干网络
class DigitsMobileNet(nn.Module):
    def __init__(self, class_num=11):
        super().__init__()
        # 加载预训练MobileNetV2的特征层（去掉分类层）
        self.net = mobilenet_v2(weights=MobileNet_V2_Weights.IMAGENET1K_V1).features
        # 自适应池化层（输出形状：1x1）
        self.avgpool = nn.AdaptiveAvgPool2d((1, 1))
        # 批量归一化
        self.bn = nn.BatchNorm1d(1280)

        # 四个独立全连接层（每个对应一个字符位置）
        self.fc1 = nn.Linear(1280, class_num)
        self.fc2 = nn.Linear(1280, class_num)
        self.fc3 = nn.Linear(1280, class_num)
        self.fc4 = nn.Linear(1280, class_num)

    def forward(self, img):
        # 特征提取与池化
        features = self.avgpool(self.net(img))  # 输出形状：(batch, 1280, 1, 1)
        features = features.view(-1, 1280)  # 展平为 (batch, 1280)
        features = self.bn(features)  # 批归一化

        # 四个分支的分类结果
        fc1 = self.fc1(features)
        fc2 = self.fc2(features)
        fc3 = self.fc3(features)
        fc4 = self.fc4(features)

        return fc1, fc2, fc3, fc4

# %%
net = DigitsResNet101()
# print(net)

# %%
# 标签平滑
# ----------------------------------- LabelSmoothEntropy ----------------------------------- #
class LabelSmoothEntropyLoss(nn.Module):
    def __init__(self, smooth=0.1, class_weights=None, size_average='mean'):
        super().__init__()
        self.size_average = size_average  # 损失平均方式（'mean'或'sum'）
        # 平滑参数，通常设置成0.1
        self.smooth = smooth
        self.class_weights = class_weights  # 类别权重（可选）

    def forward(self, preds, targets):
        """
        preds: 模型输出的原始logits（未归一化），形状为 (batch_size, num_classes)
        targets: 真实标签的索引，形状为 (batch_size,)
        """
        # 计算平滑后的标签分布
        num_classes = preds.shape[0]  # 获取类别总数
        lb_pos = 1 - self.smooth  # 真实类别的权重
        lb_neg = self.smooth / (num_classes - 1)  # 其他类别的均匀权重（原代码中的分母有误，应为类别数而非batch_size）

        # 创建平滑后的标签张量
        smoothed_lb = torch.zeros_like(preds)  # 初始化为全零
        smoothed_lb.fill_(lb_neg)  # 填充所有位置为lb_neg
        # 将真实标签位置的值设为lb_pos（scatter_的dim=1表示按列操作）
        smoothed_lb.scatter_(1, targets[:, None], lb_pos)

        # 计算log_softmax（数值稳定的概率对数）
        log_soft = F.log_softmax(preds, dim=1)

        # 应用类别权重（如果有）
        if self.class_weights is not None:
            # 扩展权重形状为(1, num_classes)，与logits相乘
            loss = -log_soft * smoothed_lb * self.class_weights[None, :]
        else:
            loss = -log_soft * smoothed_lb

        # 按样本求和（每个样本的损失是所有类别的加权和）
        loss = loss.sum(1)

        # 根据size_average参数返回结果
        if self.size_average == 'mean':
            return loss.mean()
        elif self.size_average == 'sum':
            return loss.sum()
        else:
            raise NotImplementedError("size_average must be 'mean' or 'sum'")

# %%
# 定义训练模型
class Trainer:
    def __init__(self, val=True):
        self.device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
        self.train_set = DigitsDataset(mode='train')
        # pin_memory提升CPU到GPU的传输速度; drop_last丢弃不完整 batch;collate_fn: 自定义 batch 合并逻辑动态调整裁剪宽度
        self.train_loader = DataLoader(self.train_set, batch_size=config.batch_size, shuffle=True, num_workers=6,
                                       pin_memory=True, drop_last=True, collate_fn=self.train_set.collect_fn)

        if val:
            self.val_loader = DataLoader(DigitsDataset(mode='val', aug=False), batch_size=config.batch_size,
                                         num_workers=6, pin_memory=True, drop_last=False)
        else:
            self.val_loader = None

        # 可以切换使用ResNet 和 mobilenet
        # self.model = DigitsResNet50().to(self.device)
        # self.model = DigitsMobileNet().to(self.device)
        # self.model = DigitsResNet18().to(self.device)
        self.model = DigitsResNet101().to(self.device)

        # 平滑标签
        self.criterion = LabelSmoothEntropyLoss().to(self.device)

        # optimizer可选择SGD或者Adam
        # 随机梯度下降
        # self.optimizer = SGD(self.model.parameters(), lr=config.lr, momentum=config.momentum, weight_decay=config.weights_decay,nesterov=True)
        # Adam
        # betas,控制一阶矩（梯度的移动平均）和控制二阶矩（梯度平方的移动平均）的衰减率。
        # β₁=0.9：表示梯度的移动平均更关注近期梯度（衰减率高），有助于加速收敛。β₂=0.999：二阶矩的衰减率更高，能更稳定地估计梯度方差，适合噪声较大的数据。若数据噪声大，可适当降低β₂（如0.995），以更快响应梯度变化，若模型收敛过慢，可尝试增大β₁（如0.95）以加速一阶矩的更新。
        # eps（平滑项）当梯度平方的移动平均值接近零时，eps作为分母的最小值，避免梯度更新失效
        # amsgrad 是否启用AMSGrad变种 可改进Adam在后期阶段的收敛性，避免学习率过早衰减导致的停滞
        self.optimizer = Adam(self.model.parameters(), lr=config.lr, betas=(0.9, 0.999), eps=1e-08,
                              weight_decay=config.weights_decay, amsgrad=False)

        #学习率周期动态调整 余弦退火算法
        # self.lr_scheduler = CosineAnnealingWarmRestarts(self.optimizer, 10, 2, eta_min=10e-5),eta_min=10e-4,10e-5
        # `T_0`：初始周期长度（单位：epoch 或 step），T_mult：周期倍增因子（`T_mult=2`，则每个周期长度是前一个2倍），eta_min：学习率下限
        self.lr_scheduler = CosineAnnealingWarmRestarts(self.optimizer, T_0=10, T_mult=2, eta_min=0)
        # self.lr_scheduler = (self.optimizer, [10, 20, 30], 0.5)
        self.best_acc = 0

        # 是否载入预训练模型
        if config.pretrained is not None:
            self.load_model(config.pretrained)  #加载模型（自定义函数）
            # print('load model from %s' % config.pretrained)
            if self.val_loader is not None:
                acc = self.eval()
            self.best_acc = acc
            print('Load model from %s, Eval Acc: %.2f' % (config.pretrained, acc * 100))

    def train(self):  #训练主循环
        for epoch in range(config.start_epoch, config.epoches):
            print("================================Start Training at epoch %d ================================" % (
                        epoch + 1))
            acc = self.train_epoch(epoch)  #单轮训练细节
            # 周期性验证和保存模型
            if (epoch + 1) % config.eval_interval == 0:
                print("Start Evaluation at epoch %d" % (epoch + 1))
                if self.val_loader is not None:
                    acc = self.eval()  #模型验证
                #保存最优模型
                if acc > self.best_acc:
                    os.makedirs(config.checkpoints, exist_ok=True)
                    # 更换模型时记得更换路径名
                    save_path = config.checkpoints + 'epoch-mobilenet-%d-bn-acc-%.2f.pth' % (epoch + 1, acc * 100)
                    self.save_model(save_path)
                    print('%s saved successfully...' % save_path)
                    self.best_acc = acc

    # 单轮训练细节
    def train_epoch(self, epoch):
        total_loss = 0
        corrects = 0
        tbar = tqdm(self.train_loader)  #进度条
        self.model.train()
        for i, (img, label) in enumerate(tbar):
            img, label = img.to(self.device), label.to(self.device)
            # 梯度清零
            self.optimizer.zero_grad()
            # 前向传播输出，4个数字的预测结果
            pred = self.model(img)
            # 计算总损失（4个字符的损失求和）
            loss = self.criterion(pred[0], label[:, 0]) + \
                   self.criterion(pred[1], label[:, 1]) + \
                   self.criterion(pred[2], label[:, 2]) + \
                   self.criterion(pred[3], label[:, 3]) \

            total_loss += loss.item()
            # 反向传播
            loss.backward()  # 计算梯度
            self.optimizer.step()  # 更新模型参数

            # 计算准确率（所有4个字符均正确）
            temp = torch.stack([ \
                pred[0].argmax(1) == label[:, 0], \
                pred[1].argmax(1) == label[:, 1], \
                pred[2].argmax(1) == label[:, 2], \
                pred[3].argmax(1) == label[:, 3], ], dim=1)

            corrects += torch.all(temp, dim=1).sum().item()

            # 更新进度条信息
            tbar.set_description(
                'loss: %.3f, Train Acc: %.3f' % (total_loss / (i + 1), corrects * 100 / ((i + 1) * config.batch_size)))

            # 每50个batch更新学习率(余弦退火算法)
            if (i + 1) % config.print_interval == 0:
                self.lr_scheduler.step()

        return corrects * 100 / ((i + 1) * config.batch_size)

    # 模型验证
    def eval(self):
        self.model.eval()  # 切换为评估模式
        corrects = 0
        total_loss = 0
        with torch.no_grad():  # 关闭梯度计算
            tbar = tqdm(self.val_loader)
            for i, (img, label) in enumerate(tbar):
                img, label = img.to(self.device), label.to(self.device)
                pred = self.model(img)

                loss = self.criterion(pred[0], label[:, 0]) + \
                       self.criterion(pred[1], label[:, 1]) + \
                       self.criterion(pred[2], label[:, 2]) + \
                       self.criterion(pred[3], label[:, 3]) \

                total_loss += loss.item()

                temp = torch.stack([
                    pred[0].argmax(1) == label[:, 0], \
                    pred[1].argmax(1) == label[:, 1], \
                    pred[2].argmax(1) == label[:, 2], \
                    pred[3].argmax(1) == label[:, 3], \
                    ], dim=1)

                corrects += torch.all(temp, dim=1).sum().item()
                tbar.set_description('loss: %.3f, Val Acc: %.2f' % (
                total_loss / (i + 1), corrects * 100 / ((i + 1) * config.batch_size)))
        self.model.train()  # 切换为训练模式
        return corrects / (len(self.val_loader) * config.batch_size)

    def save_model(self, save_path, save_opt=False, save_config=False):
        """保存模型、优化器和配置"""
        dicts = {}
        dicts['model'] = self.model.state_dict()
        if save_opt:
            dicts['opt'] = self.optimizer.state_dict()
        if save_config:  #将超参数保存在模型文件中
            dicts['config'] = {s: config.__getattribute__(s) for s in dir(config) if not s.startswith('_')}

        torch.save(dicts, save_path)

    def load_model(self, load_path, changed=False, save_opt=False, save_config=False):
        """加载模型、优化器和配置"""
        dicts = torch.load(load_path)
        if not changed:  # 模型结构未发生变化
            self.model.load_state_dict(dicts['model'])  #直接加载模型权重

        else:  #兼容性加载
            dicts = torch.load(load_path)['model']

            keys = list(net.state_dict().keys())  #获取当前模型的所有参数名（按当前结构）。
            values = list(dicts.values())  #获取加载的权重值,（按保存时的结构)

            new_dicts = {k: v for k, v in zip(keys, values)}  #将当前模型的参数名与加载的权重值按顺序一一对应
            self.model.load_state_dict(new_dicts)  #加载新字典

        if save_opt:
            self.optimizer.load_state_dict(dicts['opt'])  #恢复优化器的学习率、动量等状态，用于断点续训

        if save_config:  #配置参数恢复
            for k, v in dicts['config'].items():
                config.__setattr__(k, v)  #加载的配置会覆盖当前 config 的值，需确保兼容性

# %% [markdown]
# **执行训练和验证**

# %%
trainer = Trainer()
trainer.train()

# %% [markdown]
# **单模型预测**

# %%
# 定义预测模型
def predict(model_path):
    test_loader = DataLoader(DigitsDataset(mode='test'), batch_size=config.batch_size, shuffle=False, num_workers=8,
                             pin_memory=True, drop_last=False)
    results = []
    # 单个模型预测可以把另外的模型注释掉
    # res50_path = config.checkpoints + 'epoch-resnet50-64-bn-acc-76.55.pth'
    # res50_net = DigitsResNet50().cuda()
    # res50_net.load_state_dict(torch.load(res50_path)['model'])

    # res_net101 = DigitsResNet101().cuda()
    # res101_path=config.checkpoints+'epoch-DigitsResnet101-47-bn-acc-76.16.pth'
    # res_net101.load_state_dict(torch.load(res101_path)['model'])

    mb_path = config.checkpoints + 'epoch-mobilenet-33-bn-acc-73.56.pth'
    mb_net = DigitsMobileNet().cuda()
    mb_net.load_state_dict(torch.load(mb_path)['model'])

    print('Load model from %s successfully'%model_path)
    tbar = tqdm(test_loader)
    mb_net.eval() #切换模型要修改
    with torch.no_grad():
        for i, (img, img_names) in enumerate(tbar):
            img = img.cuda()
            pred = mb_net(img)

            results += [[name, code] for name, code in zip(img_names, parse2class(pred))]

    results = sorted(results, key=lambda x: x[0])

    write2csv(results)
    return results


def parse2class(prediction):
    """

     Params:
     prediction(tuple of tensor):

    """
    ch1, ch2, ch3, ch4 = prediction
    char_list = [str(i) for i in range(10)]   # ['0', '1', ..., '9']
    char_list.append('')
    ch1, ch2, ch3, ch4 = ch1.argmax(1), ch2.argmax(1), ch3.argmax(1), ch4.argmax(1)
    ch1, ch2, ch3, ch4 = [char_list[i.item()] for i in ch1], [char_list[i.item()] for i in ch2], [char_list[i.item()]
                                                                                                  for i in ch3], [
        char_list[i.item()] for i in ch4]

    res = [c1 + c2 + c3 + c4 for c1, c2, c3, c4 in zip(ch1, ch2, ch3, ch4)]

    return res


def write2csv(results):
    """

    results(list):

    """
    #定义输出文件
    df = pd.DataFrame(results, columns=['file_name', 'file_code'])
    df['file_name'] = df['file_name'].apply(lambda x: x.split('\\')[-1])
    save_name = './prediction_result/results-resnet101.csv'
    df.to_csv(save_name, sep=',', index=None)
    print('Results.saved to %s' % save_name)

# %%
predict('./user_data/model_data/checkpoints/epoch-mobilenet-33-bn-acc-73.56.pth')
torch.cuda.empty_cache()
# Out:
# Load model from ./user_data/model_data/checkpoints/epoch-mobilenet-33-bn-acc-73.56.pth successfully
#   0%|          | 0/625 [00:39<?, ?it/s]
# Results.saved to ./prediction_result/results-resnet101.csv
# [['./tcdata/mchar_test_a\\000000.png', '199'],
#  ['./tcdata/mchar_test_a\\000001.png', '290'],
#  ['./tcdata/mchar_test_a\\000002.png', '113'],
#  ['./tcdata/mchar_test_a\\000003.png', '97'],
#  ['./tcdata/mchar_test_a\\000004.png', '63'],
#  ['./tcdata/mchar_test_a\\000005.png', '639'],
#  ['./tcdata/mchar_test_a\\000006.png', '126'],
#  ['./tcdata/mchar_test_a\\000007.png', '1475'],
#  ['./tcdata/mchar_test_a\\000008.png', '48'],
#  ['./tcdata/mchar_test_a\\000009.png', '118'],
#  ['./tcdata/mchar_test_a\\000010.png', '281'],
#  ['./tcdata/mchar_test_a\\000011.png', '610'],
#  ['./tcdata/mchar_test_a\\000012.png', '60'],
#  ['./tcdata/mchar_test_a\\000013.png', '772'],
#  ['./tcdata/mchar_test_a\\000014.png', '836'],
#  ['./tcdata/mchar_test_a\\000015.png', '40'],
#  ['./tcdata/mchar_test_a\\000016.png', '29'],
#  ['./tcdata/mchar_test_a\\000017.png', '60'],
#  ['./tcdata/mchar_test_a\\000018.png', '15'],
#  ['./tcdata/mchar_test_a\\000019.png', '204'],
#  ['./tcdata/mchar_test_a\\000020.png', '284'],
#  ['./tcdata/mchar_test_a\\000021.png', '14'],
#  ['./tcdata/mchar_test_a\\000022.png', '245'],
#  ['./tcdata/mchar_test_a\\000023.png', '2001'],
#  ['./tcdata/mchar_test_a\\000024.png', '37'],
#  ['./tcdata/mchar_test_a\\000025.png', '23'],
#  ['./tcdata/mchar_test_a\\000026.png', '11'],
#  ['./tcdata/mchar_test_a\\000027.png', '157'],
#  ['./tcdata/mchar_test_a\\000028.png', '98'],
#  ['./tcdata/mchar_test_a\\000029.png', '14'],
#  ['./tcdata/mchar_test_a\\000030.png', '226'],
#  ['./tcdata/mchar_test_a\\000031.png', '545'],
#  ['./tcdata/mchar_test_a\\000032.png', '72'],
#  ['./tcdata/mchar_test_a\\000033.png', '243'],
#  ['./tcdata/mchar_test_a\\000034.png', '217'],
#  ['./tcdata/mchar_test_a\\000035.png', '176'],
#  ['./tcdata/mchar_test_a\\000036.png', '24'],
#  ['./tcdata/mchar_test_a\\000037.png', '2'],
#  ['./tcdata/mchar_test_a\\000038.png', '185'],
#  ['./tcdata/mchar_test_a\\000039.png', '28'],
#  ['./tcdata/mchar_test_a\\000040.png', '18'],
#  ['./tcdata/mchar_test_a\\000041.png', '191'],
#  ['./tcdata/mchar_test_a\\000042.png', '44'],
#  ['./tcdata/mchar_test_a\\000043.png', '81'],
#  ['./tcdata/mchar_test_a\\000044.png', '67'],
#  ['./tcdata/mchar_test_a\\000045.png', '72'],
#  ['./tcdata/mchar_test_a\\000046.png', '81'],
#  ['./tcdata/mchar_test_a\\000047.png', '29'],
#  ['./tcdata/mchar_test_a\\000048.png', '56'],
#  ['./tcdata/mchar_test_a\\000049.png', '9'],
#  ['./tcdata/mchar_test_a\\000050.png', '22'],
#  ['./tcdata/mchar_test_a\\000051.png', '247'],
#  ['./tcdata/mchar_test_a\\000052.png', '24'],
#  ['./tcdata/mchar_test_a\\000053.png', '309'],
#  ['./tcdata/mchar_test_a\\000054.png', '26'],
#  ['./tcdata/mchar_test_a\\000055.png', '34'],
#  ['./tcdata/mchar_test_a\\000056.png', '36'],
#  ['./tcdata/mchar_test_a\\000057.png', '153'],
#  ['./tcdata/mchar_test_a\\000058.png', '646'],
#  ['./tcdata/mchar_test_a\\000059.png', '160'],
#  ['./tcdata/mchar_test_a\\000060.png', '17'],
#  ['./tcdata/mchar_test_a\\000061.png', '274'],
#  ['./tcdata/mchar_test_a\\000062.png', '246'],
#  ['./tcdata/mchar_test_a\\000063.png', '648'],
#  ['./tcdata/mchar_test_a\\000064.png', '273'],
#  ['./tcdata/mchar_test_a\\000065.png', '15'],
#  ['./tcdata/mchar_test_a\\000066.png', '56'],
#  ['./tcdata/mchar_test_a\\000067.png', '64'],
#  ['./tcdata/mchar_test_a\\000068.png', '552'],
#  ['./tcdata/mchar_test_a\\000069.png', '851'],
#  ['./tcdata/mchar_test_a\\000070.png', '292'],
#  ['./tcdata/mchar_test_a\\000071.png', '833'],
#  ['./tcdata/mchar_test_a\\000072.png', '28'],
#  ['./tcdata/mchar_test_a\\000073.png', '52'],
#  ['./tcdata/mchar_test_a\\000074.png', '2'],
#  ['./tcdata/mchar_test_a\\000075.png', '612'],
#  ['./tcdata/mchar_test_a\\000076.png', '41'],
#  ['./tcdata/mchar_test_a\\000077.png', '307'],
#  ['./tcdata/mchar_test_a\\000078.png', '237'],
#  ['./tcdata/mchar_test_a\\000079.png', '36'],
#  ['./tcdata/mchar_test_a\\000080.png', '5'],
#  ['./tcdata/mchar_test_a\\000081.png', '07'],
#  ['./tcdata/mchar_test_a\\000082.png', '159'],
#  ['./tcdata/mchar_test_a\\000083.png', '228'],
#  ['./tcdata/mchar_test_a\\000084.png', '47'],
#  ['./tcdata/mchar_test_a\\000085.png', '82'],
#  ['./tcdata/mchar_test_a\\000086.png', '300'],
#  ['./tcdata/mchar_test_a\\000087.png', '44'],
#  ['./tcdata/mchar_test_a\\000088.png', '124'],
#  ['./tcdata/mchar_test_a\\000089.png', '113'],
#  ['./tcdata/mchar_test_a\\000090.png', '1376'],
#  ['./tcdata/mchar_test_a\\000091.png', '428'],
#  ['./tcdata/mchar_test_a\\000092.png', '97'],
#  ['./tcdata/mchar_test_a\\000093.png', '70'],
#  ['./tcdata/mchar_test_a\\000094.png', '4'],
#  ['./tcdata/mchar_test_a\\000095.png', '37'],
#  ['./tcdata/mchar_test_a\\000096.png', '8'],
#  ['./tcdata/mchar_test_a\\000097.png', '62'],
#  ['./tcdata/mchar_test_a\\000098.png', '204'],
#  ['./tcdata/mchar_test_a\\000099.png', '805'],
#  ['./tcdata/mchar_test_a\\000100.png', '19'],
#  ['./tcdata/mchar_test_a\\000101.png', '175'],
#  ['./tcdata/mchar_test_a\\000102.png', '2'],
#  ['./tcdata/mchar_test_a\\000103.png', '471'],
#  ['./tcdata/mchar_test_a\\000104.png', '95'],
#  ['./tcdata/mchar_test_a\\000105.png', '368'],
#  ['./tcdata/mchar_test_a\\000106.png', '31'],
#  ['./tcdata/mchar_test_a\\000107.png', '49'],
#  ['./tcdata/mchar_test_a\\000108.png', '65'],
#  ['./tcdata/mchar_test_a\\000109.png', '409'],
#  ['./tcdata/mchar_test_a\\000110.png', '1584'],
#  ['./tcdata/mchar_test_a\\000111.png', '23'],
#  ['./tcdata/mchar_test_a\\000112.png', '328'],
#  ['./tcdata/mchar_test_a\\000113.png', '539'],
#  ['./tcdata/mchar_test_a\\000114.png', '418'],
#  ['./tcdata/mchar_test_a\\000115.png', '181'],
#  ['./tcdata/mchar_test_a\\000116.png', '229'],
#  ['./tcdata/mchar_test_a\\000117.png', '45'],
#  ['./tcdata/mchar_test_a\\000118.png', '46'],
#  ['./tcdata/mchar_test_a\\000119.png', '315'],
#  ['./tcdata/mchar_test_a\\000120.png', '64'],
#  ['./tcdata/mchar_test_a\\000121.png', '5'],
#  ['./tcdata/mchar_test_a\\000122.png', '752'],
#  ['./tcdata/mchar_test_a\\000123.png', '652'],
#  ['./tcdata/mchar_test_a\\000124.png', '167'],
#  ['./tcdata/mchar_test_a\\000125.png', '193'],
#  ['./tcdata/mchar_test_a\\000126.png', '191'],
#  ['./tcdata/mchar_test_a\\000127.png', '161'],
#  ['./tcdata/mchar_test_a\\000128.png', '22'],
#  ['./tcdata/mchar_test_a\\000129.png', '93'],
#  ['./tcdata/mchar_test_a\\000130.png', '219'],
#  ['./tcdata/mchar_test_a\\000131.png', '12'],
#  ['./tcdata/mchar_test_a\\000132.png', '2'],
#  ['./tcdata/mchar_test_a\\000133.png', '9'],
#  ['./tcdata/mchar_test_a\\000134.png', '356'],
#  ['./tcdata/mchar_test_a\\000135.png', '90'],
#  ['./tcdata/mchar_test_a\\000136.png', '197'],
#  ['./tcdata/mchar_test_a\\000137.png', '209'],
#  ['./tcdata/mchar_test_a\\000138.png', '183'],
#  ['./tcdata/mchar_test_a\\000139.png', '127'],
#  ['./tcdata/mchar_test_a\\000140.png', '307'],
#  ['./tcdata/mchar_test_a\\000141.png', '788'],
#  ['./tcdata/mchar_test_a\\000142.png', '389'],
#  ['./tcdata/mchar_test_a\\000143.png', '690'],
#  ['./tcdata/mchar_test_a\\000144.png', '154'],
#  ['./tcdata/mchar_test_a\\000145.png', '21'],
#  ['./tcdata/mchar_test_a\\000146.png', '22'],
#  ['./tcdata/mchar_test_a\\000147.png', '256'],
#  ['./tcdata/mchar_test_a\\000148.png', '161'],
#  ['./tcdata/mchar_test_a\\000149.png', '146'],
#  ['./tcdata/mchar_test_a\\000150.png', '1315'],
#  ['./tcdata/mchar_test_a\\000151.png', '347'],
#  ['./tcdata/mchar_test_a\\000152.png', '139'],
#  ['./tcdata/mchar_test_a\\000153.png', '220'],
#  ['./tcdata/mchar_test_a\\000154.png', '487'],
#  ['./tcdata/mchar_test_a\\000155.png', '322'],
#  ['./tcdata/mchar_test_a\\000156.png', '46'],
#  ['./tcdata/mchar_test_a\\000157.png', '527'],
#  ['./tcdata/mchar_test_a\\000158.png', '223'],
#  ['./tcdata/mchar_test_a\\000159.png', '10'],
#  ['./tcdata/mchar_test_a\\000160.png', '237'],
#  ['./tcdata/mchar_test_a\\000161.png', '460'],
#  ['./tcdata/mchar_test_a\\000162.png', '12'],
#  ['./tcdata/mchar_test_a\\000163.png', '38'],
#  ['./tcdata/mchar_test_a\\000164.png', '311'],
#  ['./tcdata/mchar_test_a\\000165.png', '156'],
#  ['./tcdata/mchar_test_a\\000166.png', '68'],
#  ['./tcdata/mchar_test_a\\000167.png', '92'],
#  ['./tcdata/mchar_test_a\\000168.png', '530'],
#  ['./tcdata/mchar_test_a\\000169.png', '75'],
#  ['./tcdata/mchar_test_a\\000170.png', '345'],
#  ['./tcdata/mchar_test_a\\000171.png', '79'],
#  ['./tcdata/mchar_test_a\\000172.png', '52'],
#  ['./tcdata/mchar_test_a\\000173.png', '251'],
#  ['./tcdata/mchar_test_a\\000174.png', '132'],
#  ['./tcdata/mchar_test_a\\000175.png', '379'],
#  ['./tcdata/mchar_test_a\\000176.png', '525'],
#  ['./tcdata/mchar_test_a\\000177.png', '25'],
#  ['./tcdata/mchar_test_a\\000178.png', '58'],
#  ['./tcdata/mchar_test_a\\000179.png', '27'],
#  ['./tcdata/mchar_test_a\\000180.png', '133'],
#  ['./tcdata/mchar_test_a\\000181.png', '56'],
#  ['./tcdata/mchar_test_a\\000182.png', '379'],
#  ['./tcdata/mchar_test_a\\000183.png', '1882'],
#  ['./tcdata/mchar_test_a\\000184.png', '120'],
#  ['./tcdata/mchar_test_a\\000185.png', '80'],
#  ['./tcdata/mchar_test_a\\000186.png', '30'],
#  ['./tcdata/mchar_test_a\\000187.png', '16'],
#  ['./tcdata/mchar_test_a\\000188.png', '220'],
#  ['./tcdata/mchar_test_a\\000189.png', '280'],
#  ['./tcdata/mchar_test_a\\000190.png', '16'],
#  ['./tcdata/mchar_test_a\\000191.png', '2369'],
#  ['./tcdata/mchar_test_a\\000192.png', '470'],
#  ['./tcdata/mchar_test_a\\000193.png', '59'],
#  ['./tcdata/mchar_test_a\\000194.png', '964'],
#  ['./tcdata/mchar_test_a\\000195.png', '213'],
#  ['./tcdata/mchar_test_a\\000196.png', '157'],
#  ['./tcdata/mchar_test_a\\000197.png', '209'],
#  ['./tcdata/mchar_test_a\\000198.png', '163'],
#  ['./tcdata/mchar_test_a\\000199.png', '3'],
#  ['./tcdata/mchar_test_a\\000200.png', '85'],
#  ['./tcdata/mchar_test_a\\000201.png', '515'],
#  ['./tcdata/mchar_test_a\\000202.png', '91'],
#  ['./tcdata/mchar_test_a\\000203.png', '440'],
#  ['./tcdata/mchar_test_a\\000204.png', '22'],
#  ['./tcdata/mchar_test_a\\000205.png', '220'],
#  ['./tcdata/mchar_test_a\\000206.png', '1000'],
#  ['./tcdata/mchar_test_a\\000207.png', '1272'],
#  ['./tcdata/mchar_test_a\\000208.png', '61'],
#  ['./tcdata/mchar_test_a\\000209.png', '150'],
#  ['./tcdata/mchar_test_a\\000210.png', '19'],
#  ['./tcdata/mchar_test_a\\000211.png', '2'],
#  ['./tcdata/mchar_test_a\\000212.png', '154'],
#  ['./tcdata/mchar_test_a\\000213.png', '183'],
#  ['./tcdata/mchar_test_a\\000214.png', '619'],
#  ['./tcdata/mchar_test_a\\000215.png', '316'],
#  ['./tcdata/mchar_test_a\\000216.png', '946'],
#  ['./tcdata/mchar_test_a\\000217.png', '101'],
#  ['./tcdata/mchar_test_a\\000218.png', '1032'],
#  ['./tcdata/mchar_test_a\\000219.png', '180'],
#  ['./tcdata/mchar_test_a\\000220.png', '4'],
#  ['./tcdata/mchar_test_a\\000221.png', '97'],
#  ['./tcdata/mchar_test_a\\000222.png', '33'],
#  ['./tcdata/mchar_test_a\\000223.png', '237'],
#  ['./tcdata/mchar_test_a\\000224.png', '1218'],
#  ['./tcdata/mchar_test_a\\000225.png', '110'],
#  ['./tcdata/mchar_test_a\\000226.png', '300'],
#  ['./tcdata/mchar_test_a\\000227.png', '263'],
#  ['./tcdata/mchar_test_a\\000228.png', '143'],
#  ['./tcdata/mchar_test_a\\000229.png', '8'],
#  ['./tcdata/mchar_test_a\\000230.png', '140'],
#  ['./tcdata/mchar_test_a\\000231.png', '581'],
#  ['./tcdata/mchar_test_a\\000232.png', '35'],
#  ['./tcdata/mchar_test_a\\000233.png', '245'],
#  ['./tcdata/mchar_test_a\\000234.png', '3161'],
#  ['./tcdata/mchar_test_a\\000235.png', '185'],
#  ['./tcdata/mchar_test_a\\000236.png', '217'],
#  ['./tcdata/mchar_test_a\\000237.png', '223'],
#  ['./tcdata/mchar_test_a\\000238.png', '234'],
#  ['./tcdata/mchar_test_a\\000239.png', '28'],
#  ['./tcdata/mchar_test_a\\000240.png', '189'],
#  ['./tcdata/mchar_test_a\\000241.png', '37'],
#  ['./tcdata/mchar_test_a\\000242.png', '4765'],
#  ['./tcdata/mchar_test_a\\000243.png', '69'],
#  ['./tcdata/mchar_test_a\\000244.png', '984'],
#  ['./tcdata/mchar_test_a\\000245.png', '15'],
#  ['./tcdata/mchar_test_a\\000246.png', '21'],
#  ['./tcdata/mchar_test_a\\000247.png', '575'],
#  ['./tcdata/mchar_test_a\\000248.png', '26'],
#  ['./tcdata/mchar_test_a\\000249.png', '16'],
#  ['./tcdata/mchar_test_a\\000250.png', '87'],
#  ['./tcdata/mchar_test_a\\000251.png', '345'],
#  ['./tcdata/mchar_test_a\\000252.png', '150'],
#  ['./tcdata/mchar_test_a\\000253.png', '225'],
#  ['./tcdata/mchar_test_a\\000254.png', '330'],
#  ['./tcdata/mchar_test_a\\000255.png', '22'],
#  ['./tcdata/mchar_test_a\\000256.png', '94'],
#  ['./tcdata/mchar_test_a\\000257.png', '287'],
#  ['./tcdata/mchar_test_a\\000258.png', '78'],
#  ['./tcdata/mchar_test_a\\000259.png', '206'],
#  ['./tcdata/mchar_test_a\\000260.png', '217'],
#  ['./tcdata/mchar_test_a\\000261.png', '18'],
#  ['./tcdata/mchar_test_a\\000262.png', '16'],
#  ['./tcdata/mchar_test_a\\000263.png', '4'],
#  ['./tcdata/mchar_test_a\\000264.png', '5'],
#  ['./tcdata/mchar_test_a\\000265.png', '261'],
#  ['./tcdata/mchar_test_a\\000266.png', '100'],
#  ['./tcdata/mchar_test_a\\000267.png', '28'],
#  ['./tcdata/mchar_test_a\\000268.png', '555'],
#  ['./tcdata/mchar_test_a\\000269.png', '95'],
#  ['./tcdata/mchar_test_a\\000270.png', '663'],
#  ['./tcdata/mchar_test_a\\000271.png', '252'],
#  ['./tcdata/mchar_test_a\\000272.png', '163'],
#  ['./tcdata/mchar_test_a\\000273.png', '700'],
#  ['./tcdata/mchar_test_a\\000274.png', '418'],
#  ['./tcdata/mchar_test_a\\000275.png', '65'],
#  ['./tcdata/mchar_test_a\\000276.png', '696'],
#  ['./tcdata/mchar_test_a\\000277.png', '2008'],
#  ['./tcdata/mchar_test_a\\000278.png', '23'],
#  ['./tcdata/mchar_test_a\\000279.png', '346'],
#  ['./tcdata/mchar_test_a\\000280.png', '30'],
#  ['./tcdata/mchar_test_a\\000281.png', '514'],
#  ['./tcdata/mchar_test_a\\000282.png', '54'],
#  ['./tcdata/mchar_test_a\\000283.png', '125'],
#  ['./tcdata/mchar_test_a\\000284.png', '321'],
#  ['./tcdata/mchar_test_a\\000285.png', '152'],
#  ['./tcdata/mchar_test_a\\000286.png', '1955'],
#  ['./tcdata/mchar_test_a\\000287.png', '4'],
#  ['./tcdata/mchar_test_a\\000288.png', '547'],
#  ['./tcdata/mchar_test_a\\000289.png', '157'],
#  ['./tcdata/mchar_test_a\\000290.png', '353'],
#  ['./tcdata/mchar_test_a\\000291.png', '271'],
#  ['./tcdata/mchar_test_a\\000292.png', '883'],
#  ['./tcdata/mchar_test_a\\000293.png', '194'],
#  ['./tcdata/mchar_test_a\\000294.png', '2'],
#  ['./tcdata/mchar_test_a\\000295.png', '59'],
#  ['./tcdata/mchar_test_a\\000296.png', '267'],
#  ['./tcdata/mchar_test_a\\000297.png', '2350'],
#  ['./tcdata/mchar_test_a\\000298.png', '60'],
#  ['./tcdata/mchar_test_a\\000299.png', '47'],
#  ['./tcdata/mchar_test_a\\000300.png', '55'],
#  ['./tcdata/mchar_test_a\\000301.png', '913'],
#  ['./tcdata/mchar_test_a\\000302.png', '867'],
#  ['./tcdata/mchar_test_a\\000303.png', '1336'],
#  ['./tcdata/mchar_test_a\\000304.png', '150'],
#  ['./tcdata/mchar_test_a\\000305.png', '7'],
#  ['./tcdata/mchar_test_a\\000306.png', '18'],
#  ['./tcdata/mchar_test_a\\000307.png', '107'],
#  ['./tcdata/mchar_test_a\\000308.png', '34'],
#  ['./tcdata/mchar_test_a\\000309.png', '110'],
#  ['./tcdata/mchar_test_a\\000310.png', '533'],
#  ['./tcdata/mchar_test_a\\000311.png', '110'],
#  ['./tcdata/mchar_test_a\\000312.png', '2'],
#  ['./tcdata/mchar_test_a\\000313.png', '494'],
#  ['./tcdata/mchar_test_a\\000314.png', '75'],
#  ['./tcdata/mchar_test_a\\000315.png', '26'],
#  ['./tcdata/mchar_test_a\\000316.png', '27'],
#  ['./tcdata/mchar_test_a\\000317.png', '23'],
#  ['./tcdata/mchar_test_a\\000318.png', '34'],
#  ['./tcdata/mchar_test_a\\000319.png', '443'],
#  ['./tcdata/mchar_test_a\\000320.png', '291'],
#  ['./tcdata/mchar_test_a\\000321.png', '56'],
#  ['./tcdata/mchar_test_a\\000322.png', '333'],
#  ['./tcdata/mchar_test_a\\000323.png', '323'],
#  ['./tcdata/mchar_test_a\\000324.png', '22'],
#  ['./tcdata/mchar_test_a\\000325.png', '106'],
#  ['./tcdata/mchar_test_a\\000326.png', '20'],
#  ['./tcdata/mchar_test_a\\000327.png', '99'],
#  ['./tcdata/mchar_test_a\\000328.png', '396'],
#  ['./tcdata/mchar_test_a\\000329.png', '1473'],
#  ['./tcdata/mchar_test_a\\000330.png', '409'],
#  ['./tcdata/mchar_test_a\\000331.png', '180'],
#  ['./tcdata/mchar_test_a\\000332.png', '444'],
#  ['./tcdata/mchar_test_a\\000333.png', '83'],
#  ['./tcdata/mchar_test_a\\000334.png', '104'],
#  ['./tcdata/mchar_test_a\\000335.png', '692'],
#  ['./tcdata/mchar_test_a\\000336.png', '215'],
#  ['./tcdata/mchar_test_a\\000337.png', '7'],
#  ['./tcdata/mchar_test_a\\000338.png', '290'],
#  ['./tcdata/mchar_test_a\\000339.png', '125'],
#  ['./tcdata/mchar_test_a\\000340.png', '63'],
#  ['./tcdata/mchar_test_a\\000341.png', '75'],
#  ['./tcdata/mchar_test_a\\000342.png', '375'],
#  ['./tcdata/mchar_test_a\\000343.png', '709'],
#  ['./tcdata/mchar_test_a\\000344.png', '436'],
#  ['./tcdata/mchar_test_a\\000345.png', '15'],
#  ['./tcdata/mchar_test_a\\000346.png', '19'],
#  ['./tcdata/mchar_test_a\\000347.png', '180'],
#  ['./tcdata/mchar_test_a\\000348.png', '588'],
#  ['./tcdata/mchar_test_a\\000349.png', '160'],
#  ['./tcdata/mchar_test_a\\000350.png', '1001'],
#  ['./tcdata/mchar_test_a\\000351.png', '215'],
#  ['./tcdata/mchar_test_a\\000352.png', '44'],
#  ['./tcdata/mchar_test_a\\000353.png', '216'],
#  ['./tcdata/mchar_test_a\\000354.png', '9'],
#  ['./tcdata/mchar_test_a\\000355.png', '11'],
#  ['./tcdata/mchar_test_a\\000356.png', '600'],
#  ['./tcdata/mchar_test_a\\000357.png', '236'],
#  ['./tcdata/mchar_test_a\\000358.png', '74'],
#  ['./tcdata/mchar_test_a\\000359.png', '109'],
#  ['./tcdata/mchar_test_a\\000360.png', '136'],
#  ['./tcdata/mchar_test_a\\000361.png', '287'],
#  ['./tcdata/mchar_test_a\\000362.png', '70'],
#  ['./tcdata/mchar_test_a\\000363.png', '100'],
#  ['./tcdata/mchar_test_a\\000364.png', '20'],
#  ['./tcdata/mchar_test_a\\000365.png', '116'],
#  ['./tcdata/mchar_test_a\\000366.png', '444'],
#  ['./tcdata/mchar_test_a\\000367.png', '2675'],
#  ['./tcdata/mchar_test_a\\000368.png', '484'],
#  ['./tcdata/mchar_test_a\\000369.png', '281'],
#  ['./tcdata/mchar_test_a\\000370.png', '5000'],
#  ['./tcdata/mchar_test_a\\000371.png', '295'],
#  ['./tcdata/mchar_test_a\\000372.png', '28'],
#  ['./tcdata/mchar_test_a\\000373.png', '152'],
#  ['./tcdata/mchar_test_a\\000374.png', '35'],
#  ['./tcdata/mchar_test_a\\000375.png', '2446'],
#  ['./tcdata/mchar_test_a\\000376.png', '165'],
#  ['./tcdata/mchar_test_a\\000377.png', '51'],
#  ['./tcdata/mchar_test_a\\000378.png', '75'],
#  ['./tcdata/mchar_test_a\\000379.png', '44'],
#  ['./tcdata/mchar_test_a\\000380.png', '624'],
#  ['./tcdata/mchar_test_a\\000381.png', '117'],
#  ['./tcdata/mchar_test_a\\000382.png', '95'],
#  ['./tcdata/mchar_test_a\\000383.png', '313'],
#  ['./tcdata/mchar_test_a\\000384.png', '287'],
#  ['./tcdata/mchar_test_a\\000385.png', '467'],
#  ['./tcdata/mchar_test_a\\000386.png', '449'],
#  ['./tcdata/mchar_test_a\\000387.png', '63'],
#  ['./tcdata/mchar_test_a\\000388.png', '30'],
#  ['./tcdata/mchar_test_a\\000389.png', '31'],
#  ['./tcdata/mchar_test_a\\000390.png', '33'],
#  ['./tcdata/mchar_test_a\\000391.png', '18'],
#  ['./tcdata/mchar_test_a\\000392.png', '148'],
#  ['./tcdata/mchar_test_a\\000393.png', '67'],
#  ['./tcdata/mchar_test_a\\000394.png', '160'],
#  ['./tcdata/mchar_test_a\\000395.png', '78'],
#  ['./tcdata/mchar_test_a\\000396.png', '606'],
#  ['./tcdata/mchar_test_a\\000397.png', '803'],
#  ['./tcdata/mchar_test_a\\000398.png', '433'],
#  ['./tcdata/mchar_test_a\\000399.png', '42'],
#  ['./tcdata/mchar_test_a\\000400.png', '445'],
#  ['./tcdata/mchar_test_a\\000401.png', '341'],
#  ['./tcdata/mchar_test_a\\000402.png', '154'],
#  ['./tcdata/mchar_test_a\\000403.png', '129'],
#  ['./tcdata/mchar_test_a\\000404.png', '2020'],
#  ['./tcdata/mchar_test_a\\000405.png', '1710'],
#  ['./tcdata/mchar_test_a\\000406.png', '11'],
#  ['./tcdata/mchar_test_a\\000407.png', '22'],
#  ['./tcdata/mchar_test_a\\000408.png', '8'],
#  ['./tcdata/mchar_test_a\\000409.png', '1452'],
#  ['./tcdata/mchar_test_a\\000410.png', '1862'],
#  ['./tcdata/mchar_test_a\\000411.png', '736'],
#  ['./tcdata/mchar_test_a\\000412.png', '63'],
#  ['./tcdata/mchar_test_a\\000413.png', '119'],
#  ['./tcdata/mchar_test_a\\000414.png', '250'],
#  ['./tcdata/mchar_test_a\\000415.png', '20'],
#  ['./tcdata/mchar_test_a\\000416.png', '368'],
#  ['./tcdata/mchar_test_a\\000417.png', '12'],
#  ['./tcdata/mchar_test_a\\000418.png', '32'],
#  ['./tcdata/mchar_test_a\\000419.png', '207'],
#  ['./tcdata/mchar_test_a\\000420.png', '174'],
#  ['./tcdata/mchar_test_a\\000421.png', '155'],
#  ['./tcdata/mchar_test_a\\000422.png', '59'],
#  ['./tcdata/mchar_test_a\\000423.png', '7783'],
#  ['./tcdata/mchar_test_a\\000424.png', '12'],
#  ['./tcdata/mchar_test_a\\000425.png', '510'],
#  ['./tcdata/mchar_test_a\\000426.png', '64'],
#  ['./tcdata/mchar_test_a\\000427.png', '1288'],
#  ['./tcdata/mchar_test_a\\000428.png', '76'],
#  ['./tcdata/mchar_test_a\\000429.png', '858'],
#  ['./tcdata/mchar_test_a\\000430.png', '31'],
#  ['./tcdata/mchar_test_a\\000431.png', '293'],
#  ['./tcdata/mchar_test_a\\000432.png', '1280'],
#  ['./tcdata/mchar_test_a\\000433.png', '76'],
#  ['./tcdata/mchar_test_a\\000434.png', '28'],
#  ['./tcdata/mchar_test_a\\000435.png', '23'],
#  ['./tcdata/mchar_test_a\\000436.png', '372'],
#  ['./tcdata/mchar_test_a\\000437.png', '16'],
#  ['./tcdata/mchar_test_a\\000438.png', '764'],
#  ['./tcdata/mchar_test_a\\000439.png', '123'],
#  ['./tcdata/mchar_test_a\\000440.png', '15'],
#  ['./tcdata/mchar_test_a\\000441.png', '223'],
#  ['./tcdata/mchar_test_a\\000442.png', '7'],
#  ['./tcdata/mchar_test_a\\000443.png', '104'],
#  ['./tcdata/mchar_test_a\\000444.png', '417'],
#  ['./tcdata/mchar_test_a\\000445.png', '46'],
#  ['./tcdata/mchar_test_a\\000446.png', '169'],
#  ['./tcdata/mchar_test_a\\000447.png', '649'],
#  ['./tcdata/mchar_test_a\\000448.png', '81'],
#  ['./tcdata/mchar_test_a\\000449.png', '204'],
#  ['./tcdata/mchar_test_a\\000450.png', '86'],
#  ['./tcdata/mchar_test_a\\000451.png', '85'],
#  ['./tcdata/mchar_test_a\\000452.png', '25'],
#  ['./tcdata/mchar_test_a\\000453.png', '244'],
#  ['./tcdata/mchar_test_a\\000454.png', '1051'],
#  ['./tcdata/mchar_test_a\\000455.png', '3225'],
#  ['./tcdata/mchar_test_a\\000456.png', '929'],
#  ['./tcdata/mchar_test_a\\000457.png', '22'],
#  ['./tcdata/mchar_test_a\\000458.png', '223'],
#  ['./tcdata/mchar_test_a\\000459.png', '1225'],
#  ['./tcdata/mchar_test_a\\000460.png', '166'],
#  ['./tcdata/mchar_test_a\\000461.png', '100'],
#  ['./tcdata/mchar_test_a\\000462.png', '7'],
#  ['./tcdata/mchar_test_a\\000463.png', '36'],
#  ['./tcdata/mchar_test_a\\000464.png', '1048'],
#  ['./tcdata/mchar_test_a\\000465.png', '12'],
#  ['./tcdata/mchar_test_a\\000466.png', '67'],
#  ['./tcdata/mchar_test_a\\000467.png', '382'],
#  ['./tcdata/mchar_test_a\\000468.png', '1980'],
#  ['./tcdata/mchar_test_a\\000469.png', '215'],
#  ['./tcdata/mchar_test_a\\000470.png', '104'],
#  ['./tcdata/mchar_test_a\\000471.png', '171'],
#  ['./tcdata/mchar_test_a\\000472.png', '29'],
#  ['./tcdata/mchar_test_a\\000473.png', '1500'],
#  ['./tcdata/mchar_test_a\\000474.png', '200'],
#  ['./tcdata/mchar_test_a\\000475.png', '908'],
#  ['./tcdata/mchar_test_a\\000476.png', '586'],
#  ['./tcdata/mchar_test_a\\000477.png', '18'],
#  ['./tcdata/mchar_test_a\\000478.png', '25'],
#  ['./tcdata/mchar_test_a\\000479.png', '2635'],
#  ['./tcdata/mchar_test_a\\000480.png', '201'],
#  ['./tcdata/mchar_test_a\\000481.png', '145'],
#  ['./tcdata/mchar_test_a\\000482.png', '10'],
#  ['./tcdata/mchar_test_a\\000483.png', '283'],
#  ['./tcdata/mchar_test_a\\000484.png', '86'],
#  ['./tcdata/mchar_test_a\\000485.png', '39'],
#  ['./tcdata/mchar_test_a\\000486.png', '1051'],
#  ['./tcdata/mchar_test_a\\000487.png', '542'],
#  ['./tcdata/mchar_test_a\\000488.png', '293'],
#  ['./tcdata/mchar_test_a\\000489.png', '94'],
#  ['./tcdata/mchar_test_a\\000490.png', '104'],
#  ['./tcdata/mchar_test_a\\000491.png', '274'],
#  ['./tcdata/mchar_test_a\\000492.png', '225'],
#  ['./tcdata/mchar_test_a\\000493.png', '106'],
#  ['./tcdata/mchar_test_a\\000494.png', '32'],
#  ['./tcdata/mchar_test_a\\000495.png', '105'],
#  ['./tcdata/mchar_test_a\\000496.png', '7'],
#  ['./tcdata/mchar_test_a\\000497.png', '75'],
#  ['./tcdata/mchar_test_a\\000498.png', '50'],
#  ['./tcdata/mchar_test_a\\000499.png', '1252'],
#  ['./tcdata/mchar_test_a\\000500.png', '65'],
#  ['./tcdata/mchar_test_a\\000501.png', '238'],
#  ['./tcdata/mchar_test_a\\000502.png', '758'],
#  ['./tcdata/mchar_test_a\\000503.png', '48'],
#  ['./tcdata/mchar_test_a\\000504.png', '107'],
#  ['./tcdata/mchar_test_a\\000505.png', '387'],
#  ['./tcdata/mchar_test_a\\000506.png', '388'],
#  ['./tcdata/mchar_test_a\\000507.png', '31'],
#  ['./tcdata/mchar_test_a\\000508.png', '62'],
#  ['./tcdata/mchar_test_a\\000509.png', '110'],
#  ['./tcdata/mchar_test_a\\000510.png', '12'],
#  ['./tcdata/mchar_test_a\\000511.png', '128'],
#  ['./tcdata/mchar_test_a\\000512.png', '9730'],
#  ['./tcdata/mchar_test_a\\000513.png', '117'],
#  ['./tcdata/mchar_test_a\\000514.png', '65'],
#  ['./tcdata/mchar_test_a\\000515.png', '300'],
#  ['./tcdata/mchar_test_a\\000516.png', '181'],
#  ['./tcdata/mchar_test_a\\000517.png', '43'],
#  ['./tcdata/mchar_test_a\\000518.png', '21'],
#  ['./tcdata/mchar_test_a\\000519.png', '447'],
#  ['./tcdata/mchar_test_a\\000520.png', '10'],
#  ['./tcdata/mchar_test_a\\000521.png', '65'],
#  ['./tcdata/mchar_test_a\\000522.png', '501'],
#  ['./tcdata/mchar_test_a\\000523.png', '111'],
#  ['./tcdata/mchar_test_a\\000524.png', '211'],
#  ['./tcdata/mchar_test_a\\000525.png', '66'],
#  ['./tcdata/mchar_test_a\\000526.png', '309'],
#  ['./tcdata/mchar_test_a\\000527.png', '99'],
#  ['./tcdata/mchar_test_a\\000528.png', '2380'],
#  ['./tcdata/mchar_test_a\\000529.png', '317'],
#  ['./tcdata/mchar_test_a\\000530.png', '106'],
#  ['./tcdata/mchar_test_a\\000531.png', '252'],
#  ['./tcdata/mchar_test_a\\000532.png', '298'],
#  ['./tcdata/mchar_test_a\\000533.png', '25'],
#  ['./tcdata/mchar_test_a\\000534.png', '90'],
#  ['./tcdata/mchar_test_a\\000535.png', '427'],
#  ['./tcdata/mchar_test_a\\000536.png', '302'],
#  ['./tcdata/mchar_test_a\\000537.png', '49'],
#  ['./tcdata/mchar_test_a\\000538.png', '3'],
#  ['./tcdata/mchar_test_a\\000539.png', '174'],
#  ['./tcdata/mchar_test_a\\000540.png', '143'],
#  ['./tcdata/mchar_test_a\\000541.png', '12'],
#  ['./tcdata/mchar_test_a\\000542.png', '438'],
#  ['./tcdata/mchar_test_a\\000543.png', '66'],
#  ['./tcdata/mchar_test_a\\000544.png', '468'],
#  ['./tcdata/mchar_test_a\\000545.png', '57'],
#  ['./tcdata/mchar_test_a\\000546.png', '1333'],
#  ['./tcdata/mchar_test_a\\000547.png', '77'],
#  ['./tcdata/mchar_test_a\\000548.png', '21'],
#  ['./tcdata/mchar_test_a\\000549.png', '280'],
#  ['./tcdata/mchar_test_a\\000550.png', '336'],
#  ['./tcdata/mchar_test_a\\000551.png', '130'],
#  ['./tcdata/mchar_test_a\\000552.png', '8'],
#  ['./tcdata/mchar_test_a\\000553.png', '174'],
#  ['./tcdata/mchar_test_a\\000554.png', '194'],
#  ['./tcdata/mchar_test_a\\000555.png', '16'],
#  ['./tcdata/mchar_test_a\\000556.png', '128'],
#  ['./tcdata/mchar_test_a\\000557.png', '38'],
#  ['./tcdata/mchar_test_a\\000558.png', '597'],
#  ['./tcdata/mchar_test_a\\000559.png', '118'],
#  ['./tcdata/mchar_test_a\\000560.png', '59'],
#  ['./tcdata/mchar_test_a\\000561.png', '15'],
#  ['./tcdata/mchar_test_a\\000562.png', '133'],
#  ['./tcdata/mchar_test_a\\000563.png', '922'],
#  ['./tcdata/mchar_test_a\\000564.png', '20'],
#  ['./tcdata/mchar_test_a\\000565.png', '208'],
#  ['./tcdata/mchar_test_a\\000566.png', '41'],
#  ['./tcdata/mchar_test_a\\000567.png', '21'],
#  ['./tcdata/mchar_test_a\\000568.png', '203'],
#  ['./tcdata/mchar_test_a\\000569.png', '58'],
#  ['./tcdata/mchar_test_a\\000570.png', '276'],
#  ['./tcdata/mchar_test_a\\000571.png', '129'],
#  ['./tcdata/mchar_test_a\\000572.png', '69'],
#  ['./tcdata/mchar_test_a\\000573.png', '90'],
#  ['./tcdata/mchar_test_a\\000574.png', '158'],
#  ['./tcdata/mchar_test_a\\000575.png', '324'],
#  ['./tcdata/mchar_test_a\\000576.png', '630'],
#  ['./tcdata/mchar_test_a\\000577.png', '212'],
#  ['./tcdata/mchar_test_a\\000578.png', '35'],
#  ['./tcdata/mchar_test_a\\000579.png', '273'],
#  ['./tcdata/mchar_test_a\\000580.png', '2'],
#  ['./tcdata/mchar_test_a\\000581.png', '106'],
#  ['./tcdata/mchar_test_a\\000582.png', '274'],
#  ['./tcdata/mchar_test_a\\000583.png', '68'],
#  ['./tcdata/mchar_test_a\\000584.png', '651'],
#  ['./tcdata/mchar_test_a\\000585.png', '266'],
#  ['./tcdata/mchar_test_a\\000586.png', '151'],
#  ['./tcdata/mchar_test_a\\000587.png', '227'],
#  ['./tcdata/mchar_test_a\\000588.png', '699'],
#  ['./tcdata/mchar_test_a\\000589.png', '55'],
#  ['./tcdata/mchar_test_a\\000590.png', '131'],
#  ['./tcdata/mchar_test_a\\000591.png', '118'],
#  ['./tcdata/mchar_test_a\\000592.png', '11'],
#  ['./tcdata/mchar_test_a\\000593.png', '25'],
#  ['./tcdata/mchar_test_a\\000594.png', '38'],
#  ['./tcdata/mchar_test_a\\000595.png', '24'],
#  ['./tcdata/mchar_test_a\\000596.png', '3101'],
#  ['./tcdata/mchar_test_a\\000597.png', '321'],
#  ['./tcdata/mchar_test_a\\000598.png', '1690'],
#  ['./tcdata/mchar_test_a\\000599.png', '3'],
#  ['./tcdata/mchar_test_a\\000600.png', '164'],
#  ['./tcdata/mchar_test_a\\000601.png', '209'],
#  ['./tcdata/mchar_test_a\\000602.png', '287'],
#  ['./tcdata/mchar_test_a\\000603.png', '389'],
#  ['./tcdata/mchar_test_a\\000604.png', '234'],
#  ['./tcdata/mchar_test_a\\000605.png', '194'],
#  ['./tcdata/mchar_test_a\\000606.png', '477'],
#  ['./tcdata/mchar_test_a\\000607.png', '12'],
#  ['./tcdata/mchar_test_a\\000608.png', '225'],
#  ['./tcdata/mchar_test_a\\000609.png', '295'],
#  ['./tcdata/mchar_test_a\\000610.png', '47'],
#  ['./tcdata/mchar_test_a\\000611.png', '251'],
#  ['./tcdata/mchar_test_a\\000612.png', '151'],
#  ['./tcdata/mchar_test_a\\000613.png', '29'],
#  ['./tcdata/mchar_test_a\\000614.png', '117'],
#  ['./tcdata/mchar_test_a\\000615.png', '28'],
#  ['./tcdata/mchar_test_a\\000616.png', '147'],
#  ['./tcdata/mchar_test_a\\000617.png', '297'],
#  ['./tcdata/mchar_test_a\\000618.png', '46'],
#  ['./tcdata/mchar_test_a\\000619.png', '21'],
#  ['./tcdata/mchar_test_a\\000620.png', '990'],
#  ['./tcdata/mchar_test_a\\000621.png', '9'],
#  ['./tcdata/mchar_test_a\\000622.png', '24'],
#  ['./tcdata/mchar_test_a\\000623.png', '814'],
#  ['./tcdata/mchar_test_a\\000624.png', '75'],
#  ['./tcdata/mchar_test_a\\000625.png', '15'],
#  ['./tcdata/mchar_test_a\\000626.png', '2'],
#  ['./tcdata/mchar_test_a\\000627.png', '1546'],
#  ['./tcdata/mchar_test_a\\000628.png', '129'],
#  ['./tcdata/mchar_test_a\\000629.png', '182'],
#  ['./tcdata/mchar_test_a\\000630.png', '217'],
#  ['./tcdata/mchar_test_a\\000631.png', '36'],
#  ['./tcdata/mchar_test_a\\000632.png', '225'],
#  ['./tcdata/mchar_test_a\\000633.png', '192'],
#  ['./tcdata/mchar_test_a\\000634.png', '188'],
#  ['./tcdata/mchar_test_a\\000635.png', '298'],
#  ['./tcdata/mchar_test_a\\000636.png', '15'],
#  ['./tcdata/mchar_test_a\\000637.png', '61'],
#  ['./tcdata/mchar_test_a\\000638.png', '155'],
#  ['./tcdata/mchar_test_a\\000639.png', '873'],
#  ['./tcdata/mchar_test_a\\000640.png', '455'],
#  ['./tcdata/mchar_test_a\\000641.png', '97'],
#  ['./tcdata/mchar_test_a\\000642.png', '495'],
#  ['./tcdata/mchar_test_a\\000643.png', '280'],
#  ['./tcdata/mchar_test_a\\000644.png', '564'],
#  ['./tcdata/mchar_test_a\\000645.png', '218'],
#  ['./tcdata/mchar_test_a\\000646.png', '78'],
#  ['./tcdata/mchar_test_a\\000647.png', '500'],
#  ['./tcdata/mchar_test_a\\000648.png', '320'],
#  ['./tcdata/mchar_test_a\\000649.png', '280'],
#  ['./tcdata/mchar_test_a\\000650.png', '576'],
#  ['./tcdata/mchar_test_a\\000651.png', '382'],
#  ['./tcdata/mchar_test_a\\000652.png', '1783'],
#  ['./tcdata/mchar_test_a\\000653.png', '1415'],
#  ['./tcdata/mchar_test_a\\000654.png', '110'],
#  ['./tcdata/mchar_test_a\\000655.png', '220'],
#  ['./tcdata/mchar_test_a\\000656.png', '22'],
#  ['./tcdata/mchar_test_a\\000657.png', '140'],
#  ['./tcdata/mchar_test_a\\000658.png', '25'],
#  ['./tcdata/mchar_test_a\\000659.png', '337'],
#  ['./tcdata/mchar_test_a\\000660.png', '419'],
#  ['./tcdata/mchar_test_a\\000661.png', '111'],
#  ['./tcdata/mchar_test_a\\000662.png', '265'],
#  ['./tcdata/mchar_test_a\\000663.png', '2395'],
#  ['./tcdata/mchar_test_a\\000664.png', '454'],
#  ['./tcdata/mchar_test_a\\000665.png', '134'],
#  ['./tcdata/mchar_test_a\\000666.png', '345'],
#  ['./tcdata/mchar_test_a\\000667.png', '200'],
#  ['./tcdata/mchar_test_a\\000668.png', '363'],
#  ['./tcdata/mchar_test_a\\000669.png', '272'],
#  ['./tcdata/mchar_test_a\\000670.png', '2133'],
#  ['./tcdata/mchar_test_a\\000671.png', '1433'],
#  ['./tcdata/mchar_test_a\\000672.png', '293'],
#  ['./tcdata/mchar_test_a\\000673.png', '3040'],
#  ['./tcdata/mchar_test_a\\000674.png', '1547'],
#  ['./tcdata/mchar_test_a\\000675.png', '116'],
#  ['./tcdata/mchar_test_a\\000676.png', '8'],
#  ['./tcdata/mchar_test_a\\000677.png', '29'],
#  ['./tcdata/mchar_test_a\\000678.png', '616'],
#  ['./tcdata/mchar_test_a\\000679.png', '306'],
#  ['./tcdata/mchar_test_a\\000680.png', '143'],
#  ['./tcdata/mchar_test_a\\000681.png', '104'],
#  ['./tcdata/mchar_test_a\\000682.png', '477'],
#  ['./tcdata/mchar_test_a\\000683.png', '2435'],
#  ['./tcdata/mchar_test_a\\000684.png', '20'],
#  ['./tcdata/mchar_test_a\\000685.png', '24'],
#  ['./tcdata/mchar_test_a\\000686.png', '21'],
#  ['./tcdata/mchar_test_a\\000687.png', '34'],
#  ['./tcdata/mchar_test_a\\000688.png', '408'],
#  ['./tcdata/mchar_test_a\\000689.png', '397'],
#  ['./tcdata/mchar_test_a\\000690.png', '48'],
#  ['./tcdata/mchar_test_a\\000691.png', '9'],
#  ['./tcdata/mchar_test_a\\000692.png', '51'],
#  ['./tcdata/mchar_test_a\\000693.png', '19'],
#  ['./tcdata/mchar_test_a\\000694.png', '87'],
#  ['./tcdata/mchar_test_a\\000695.png', '147'],
#  ['./tcdata/mchar_test_a\\000696.png', '43'],
#  ['./tcdata/mchar_test_a\\000697.png', '293'],
#  ['./tcdata/mchar_test_a\\000698.png', '252'],
#  ['./tcdata/mchar_test_a\\000699.png', '124'],
#  ['./tcdata/mchar_test_a\\000700.png', '660'],
#  ['./tcdata/mchar_test_a\\000701.png', '223'],
#  ['./tcdata/mchar_test_a\\000702.png', '7'],
#  ['./tcdata/mchar_test_a\\000703.png', '322'],
#  ['./tcdata/mchar_test_a\\000704.png', '260'],
#  ['./tcdata/mchar_test_a\\000705.png', '132'],
#  ['./tcdata/mchar_test_a\\000706.png', '734'],
#  ['./tcdata/mchar_test_a\\000707.png', '56'],
#  ['./tcdata/mchar_test_a\\000708.png', '217'],
#  ['./tcdata/mchar_test_a\\000709.png', '4630'],
#  ['./tcdata/mchar_test_a\\000710.png', '392'],
#  ['./tcdata/mchar_test_a\\000711.png', '65'],
#  ['./tcdata/mchar_test_a\\000712.png', '948'],
#  ['./tcdata/mchar_test_a\\000713.png', '53'],
#  ['./tcdata/mchar_test_a\\000714.png', '221'],
#  ['./tcdata/mchar_test_a\\000715.png', '125'],
#  ['./tcdata/mchar_test_a\\000716.png', '124'],
#  ['./tcdata/mchar_test_a\\000717.png', '278'],
#  ['./tcdata/mchar_test_a\\000718.png', '141'],
#  ['./tcdata/mchar_test_a\\000719.png', '470'],
#  ['./tcdata/mchar_test_a\\000720.png', '50'],
#  ['./tcdata/mchar_test_a\\000721.png', '413'],
#  ['./tcdata/mchar_test_a\\000722.png', '27'],
#  ['./tcdata/mchar_test_a\\000723.png', '522'],
#  ['./tcdata/mchar_test_a\\000724.png', '115'],
#  ['./tcdata/mchar_test_a\\000725.png', '401'],
#  ['./tcdata/mchar_test_a\\000726.png', '160'],
#  ['./tcdata/mchar_test_a\\000727.png', '226'],
#  ['./tcdata/mchar_test_a\\000728.png', '1380'],
#  ['./tcdata/mchar_test_a\\000729.png', '99'],
#  ['./tcdata/mchar_test_a\\000730.png', '30'],
#  ['./tcdata/mchar_test_a\\000731.png', '1722'],
#  ['./tcdata/mchar_test_a\\000732.png', '72'],
#  ['./tcdata/mchar_test_a\\000733.png', '43'],
#  ['./tcdata/mchar_test_a\\000734.png', '185'],
#  ['./tcdata/mchar_test_a\\000735.png', '55'],
#  ['./tcdata/mchar_test_a\\000736.png', '585'],
#  ['./tcdata/mchar_test_a\\000737.png', '6'],
#  ['./tcdata/mchar_test_a\\000738.png', '255'],
#  ['./tcdata/mchar_test_a\\000739.png', '21'],
#  ['./tcdata/mchar_test_a\\000740.png', '129'],
#  ['./tcdata/mchar_test_a\\000741.png', '80'],
#  ['./tcdata/mchar_test_a\\000742.png', '300'],
#  ['./tcdata/mchar_test_a\\000743.png', '225'],
#  ['./tcdata/mchar_test_a\\000744.png', '126'],
#  ['./tcdata/mchar_test_a\\000745.png', '98'],
#  ['./tcdata/mchar_test_a\\000746.png', '387'],
#  ['./tcdata/mchar_test_a\\000747.png', '35'],
#  ['./tcdata/mchar_test_a\\000748.png', '1495'],
#  ['./tcdata/mchar_test_a\\000749.png', '96'],
#  ['./tcdata/mchar_test_a\\000750.png', '300'],
#  ['./tcdata/mchar_test_a\\000751.png', '1107'],
#  ['./tcdata/mchar_test_a\\000752.png', '703'],
#  ['./tcdata/mchar_test_a\\000753.png', '428'],
#  ['./tcdata/mchar_test_a\\000754.png', '87'],
#  ['./tcdata/mchar_test_a\\000755.png', '283'],
#  ['./tcdata/mchar_test_a\\000756.png', '152'],
#  ['./tcdata/mchar_test_a\\000757.png', '112'],
#  ['./tcdata/mchar_test_a\\000758.png', '99'],
#  ['./tcdata/mchar_test_a\\000759.png', '180'],
#  ['./tcdata/mchar_test_a\\000760.png', '51'],
#  ['./tcdata/mchar_test_a\\000761.png', '161'],
#  ['./tcdata/mchar_test_a\\000762.png', '900'],
#  ['./tcdata/mchar_test_a\\000763.png', '1'],
#  ['./tcdata/mchar_test_a\\000764.png', '410'],
#  ['./tcdata/mchar_test_a\\000765.png', '585'],
#  ['./tcdata/mchar_test_a\\000766.png', '336'],
#  ['./tcdata/mchar_test_a\\000767.png', '426'],
#  ['./tcdata/mchar_test_a\\000768.png', '2877'],
#  ['./tcdata/mchar_test_a\\000769.png', '74'],
#  ['./tcdata/mchar_test_a\\000770.png', '514'],
#  ['./tcdata/mchar_test_a\\000771.png', '480'],
#  ['./tcdata/mchar_test_a\\000772.png', '145'],
#  ['./tcdata/mchar_test_a\\000773.png', '343'],
#  ['./tcdata/mchar_test_a\\000774.png', '137'],
#  ['./tcdata/mchar_test_a\\000775.png', '12'],
#  ['./tcdata/mchar_test_a\\000776.png', '41'],
#  ['./tcdata/mchar_test_a\\000777.png', '71'],
#  ['./tcdata/mchar_test_a\\000778.png', '80'],
#  ['./tcdata/mchar_test_a\\000779.png', '42'],
#  ['./tcdata/mchar_test_a\\000780.png', '367'],
#  ['./tcdata/mchar_test_a\\000781.png', '106'],
#  ['./tcdata/mchar_test_a\\000782.png', '20'],
#  ['./tcdata/mchar_test_a\\000783.png', '102'],
#  ['./tcdata/mchar_test_a\\000784.png', '292'],
#  ['./tcdata/mchar_test_a\\000785.png', '8'],
#  ['./tcdata/mchar_test_a\\000786.png', '343'],
#  ['./tcdata/mchar_test_a\\000787.png', '373'],
#  ['./tcdata/mchar_test_a\\000788.png', '178'],
#  ['./tcdata/mchar_test_a\\000789.png', '355'],
#  ['./tcdata/mchar_test_a\\000790.png', '381'],
#  ['./tcdata/mchar_test_a\\000791.png', '242'],
#  ['./tcdata/mchar_test_a\\000792.png', '46'],
#  ['./tcdata/mchar_test_a\\000793.png', '293'],
#  ['./tcdata/mchar_test_a\\000794.png', '9'],
#  ['./tcdata/mchar_test_a\\000795.png', '58'],
#  ['./tcdata/mchar_test_a\\000796.png', '13'],
#  ['./tcdata/mchar_test_a\\000797.png', '15'],
#  ['./tcdata/mchar_test_a\\000798.png', '122'],
#  ['./tcdata/mchar_test_a\\000799.png', '35'],
#  ['./tcdata/mchar_test_a\\000800.png', '21'],
#  ['./tcdata/mchar_test_a\\000801.png', '434'],
#  ['./tcdata/mchar_test_a\\000802.png', '6'],
#  ['./tcdata/mchar_test_a\\000803.png', '9'],
#  ['./tcdata/mchar_test_a\\000804.png', '136'],
#  ['./tcdata/mchar_test_a\\000805.png', '25'],
#  ['./tcdata/mchar_test_a\\000806.png', '9'],
#  ['./tcdata/mchar_test_a\\000807.png', '1621'],
#  ['./tcdata/mchar_test_a\\000808.png', '21'],
#  ['./tcdata/mchar_test_a\\000809.png', '672'],
#  ['./tcdata/mchar_test_a\\000810.png', '11'],
#  ['./tcdata/mchar_test_a\\000811.png', '155'],
#  ['./tcdata/mchar_test_a\\000812.png', '95'],
#  ['./tcdata/mchar_test_a\\000813.png', '70'],
#  ['./tcdata/mchar_test_a\\000814.png', '21'],
#  ['./tcdata/mchar_test_a\\000815.png', '230'],
#  ['./tcdata/mchar_test_a\\000816.png', '285'],
#  ['./tcdata/mchar_test_a\\000817.png', '396'],
#  ['./tcdata/mchar_test_a\\000818.png', '507'],
#  ['./tcdata/mchar_test_a\\000819.png', '210'],
#  ['./tcdata/mchar_test_a\\000820.png', '1981'],
#  ['./tcdata/mchar_test_a\\000821.png', '47'],
#  ['./tcdata/mchar_test_a\\000822.png', '30'],
#  ['./tcdata/mchar_test_a\\000823.png', '5'],
#  ['./tcdata/mchar_test_a\\000824.png', '52'],
#  ['./tcdata/mchar_test_a\\000825.png', '492'],
#  ['./tcdata/mchar_test_a\\000826.png', '114'],
#  ['./tcdata/mchar_test_a\\000827.png', '424'],
#  ['./tcdata/mchar_test_a\\000828.png', '191'],
#  ['./tcdata/mchar_test_a\\000829.png', '37'],
#  ['./tcdata/mchar_test_a\\000830.png', '688'],
#  ['./tcdata/mchar_test_a\\000831.png', '26'],
#  ['./tcdata/mchar_test_a\\000832.png', '497'],
#  ['./tcdata/mchar_test_a\\000833.png', '214'],
#  ['./tcdata/mchar_test_a\\000834.png', '133'],
#  ['./tcdata/mchar_test_a\\000835.png', '163'],
#  ['./tcdata/mchar_test_a\\000836.png', '40'],
#  ['./tcdata/mchar_test_a\\000837.png', '6'],
#  ['./tcdata/mchar_test_a\\000838.png', '165'],
#  ['./tcdata/mchar_test_a\\000839.png', '22'],
#  ['./tcdata/mchar_test_a\\000840.png', '187'],
#  ['./tcdata/mchar_test_a\\000841.png', '121'],
#  ['./tcdata/mchar_test_a\\000842.png', '2'],
#  ['./tcdata/mchar_test_a\\000843.png', '88'],
#  ['./tcdata/mchar_test_a\\000844.png', '655'],
#  ['./tcdata/mchar_test_a\\000845.png', '35'],
#  ['./tcdata/mchar_test_a\\000846.png', '104'],
#  ['./tcdata/mchar_test_a\\000847.png', '8'],
#  ['./tcdata/mchar_test_a\\000848.png', '33'],
#  ['./tcdata/mchar_test_a\\000849.png', '335'],
#  ['./tcdata/mchar_test_a\\000850.png', '500'],
#  ['./tcdata/mchar_test_a\\000851.png', '136'],
#  ['./tcdata/mchar_test_a\\000852.png', '56'],
#  ['./tcdata/mchar_test_a\\000853.png', '108'],
#  ['./tcdata/mchar_test_a\\000854.png', '210'],
#  ['./tcdata/mchar_test_a\\000855.png', '80'],
#  ['./tcdata/mchar_test_a\\000856.png', '197'],
#  ['./tcdata/mchar_test_a\\000857.png', '3'],
#  ['./tcdata/mchar_test_a\\000858.png', '31'],
#  ['./tcdata/mchar_test_a\\000859.png', '251'],
#  ['./tcdata/mchar_test_a\\000860.png', '26'],
#  ['./tcdata/mchar_test_a\\000861.png', '8'],
#  ['./tcdata/mchar_test_a\\000862.png', '92'],
#  ['./tcdata/mchar_test_a\\000863.png', '33'],
#  ['./tcdata/mchar_test_a\\000864.png', '27'],
#  ['./tcdata/mchar_test_a\\000865.png', '54'],
#  ['./tcdata/mchar_test_a\\000866.png', '10'],
#  ['./tcdata/mchar_test_a\\000867.png', '99'],
#  ['./tcdata/mchar_test_a\\000868.png', '26'],
#  ['./tcdata/mchar_test_a\\000869.png', '41'],
#  ['./tcdata/mchar_test_a\\000870.png', '53'],
#  ['./tcdata/mchar_test_a\\000871.png', '22'],
#  ['./tcdata/mchar_test_a\\000872.png', '351'],
#  ['./tcdata/mchar_test_a\\000873.png', '454'],
#  ['./tcdata/mchar_test_a\\000874.png', '149'],
#  ['./tcdata/mchar_test_a\\000875.png', '363'],
#  ['./tcdata/mchar_test_a\\000876.png', '520'],
#  ['./tcdata/mchar_test_a\\000877.png', '52'],
#  ['./tcdata/mchar_test_a\\000878.png', '152'],
#  ['./tcdata/mchar_test_a\\000879.png', '270'],
#  ['./tcdata/mchar_test_a\\000880.png', '91'],
#  ['./tcdata/mchar_test_a\\000881.png', '42'],
#  ['./tcdata/mchar_test_a\\000882.png', '160'],
#  ['./tcdata/mchar_test_a\\000883.png', '1435'],
#  ['./tcdata/mchar_test_a\\000884.png', '131'],
#  ['./tcdata/mchar_test_a\\000885.png', '141'],
#  ['./tcdata/mchar_test_a\\000886.png', '318'],
#  ['./tcdata/mchar_test_a\\000887.png', '27'],
#  ['./tcdata/mchar_test_a\\000888.png', '423'],
#  ['./tcdata/mchar_test_a\\000889.png', '2'],
#  ['./tcdata/mchar_test_a\\000890.png', '5'],
#  ['./tcdata/mchar_test_a\\000891.png', '123'],
#  ['./tcdata/mchar_test_a\\000892.png', '204'],
#  ['./tcdata/mchar_test_a\\000893.png', '232'],
#  ['./tcdata/mchar_test_a\\000894.png', '853'],
#  ['./tcdata/mchar_test_a\\000895.png', '664'],
#  ['./tcdata/mchar_test_a\\000896.png', '1368'],
#  ['./tcdata/mchar_test_a\\000897.png', '32'],
#  ['./tcdata/mchar_test_a\\000898.png', '83'],
#  ['./tcdata/mchar_test_a\\000899.png', '235'],
#  ['./tcdata/mchar_test_a\\000900.png', '639'],
#  ['./tcdata/mchar_test_a\\000901.png', '568'],
#  ['./tcdata/mchar_test_a\\000902.png', '397'],
#  ['./tcdata/mchar_test_a\\000903.png', '2611'],
#  ['./tcdata/mchar_test_a\\000904.png', '140'],
#  ['./tcdata/mchar_test_a\\000905.png', '379'],
#  ['./tcdata/mchar_test_a\\000906.png', '35'],
#  ['./tcdata/mchar_test_a\\000907.png', '380'],
#  ['./tcdata/mchar_test_a\\000908.png', '78'],
#  ['./tcdata/mchar_test_a\\000909.png', '92'],
#  ['./tcdata/mchar_test_a\\000910.png', '15'],
#  ['./tcdata/mchar_test_a\\000911.png', '931'],
#  ['./tcdata/mchar_test_a\\000912.png', '778'],
#  ['./tcdata/mchar_test_a\\000913.png', '1080'],
#  ['./tcdata/mchar_test_a\\000914.png', '19'],
#  ['./tcdata/mchar_test_a\\000915.png', '291'],
#  ['./tcdata/mchar_test_a\\000916.png', '156'],
#  ['./tcdata/mchar_test_a\\000917.png', '235'],
#  ['./tcdata/mchar_test_a\\000918.png', '53'],
#  ['./tcdata/mchar_test_a\\000919.png', '121'],
#  ['./tcdata/mchar_test_a\\000920.png', '218'],
#  ['./tcdata/mchar_test_a\\000921.png', '1122'],
#  ['./tcdata/mchar_test_a\\000922.png', '174'],
#  ['./tcdata/mchar_test_a\\000923.png', '57'],
#  ['./tcdata/mchar_test_a\\000924.png', '105'],
#  ['./tcdata/mchar_test_a\\000925.png', '221'],
#  ['./tcdata/mchar_test_a\\000926.png', '282'],
#  ['./tcdata/mchar_test_a\\000927.png', '243'],
#  ['./tcdata/mchar_test_a\\000928.png', '287'],
#  ['./tcdata/mchar_test_a\\000929.png', '69'],
#  ['./tcdata/mchar_test_a\\000930.png', '15'],
#  ['./tcdata/mchar_test_a\\000931.png', '313'],
#  ['./tcdata/mchar_test_a\\000932.png', '436'],
#  ['./tcdata/mchar_test_a\\000933.png', '32'],
#  ['./tcdata/mchar_test_a\\000934.png', '626'],
#  ['./tcdata/mchar_test_a\\000935.png', '140'],
#  ['./tcdata/mchar_test_a\\000936.png', '730'],
#  ['./tcdata/mchar_test_a\\000937.png', '470'],
#  ['./tcdata/mchar_test_a\\000938.png', '314'],
#  ['./tcdata/mchar_test_a\\000939.png', '421'],
#  ['./tcdata/mchar_test_a\\000940.png', '65'],
#  ['./tcdata/mchar_test_a\\000941.png', '24'],
#  ['./tcdata/mchar_test_a\\000942.png', '372'],
#  ['./tcdata/mchar_test_a\\000943.png', '320'],
#  ['./tcdata/mchar_test_a\\000944.png', '447'],
#  ['./tcdata/mchar_test_a\\000945.png', '210'],
#  ['./tcdata/mchar_test_a\\000946.png', '449'],
#  ['./tcdata/mchar_test_a\\000947.png', '62'],
#  ['./tcdata/mchar_test_a\\000948.png', '63'],
#  ['./tcdata/mchar_test_a\\000949.png', '1626'],
#  ['./tcdata/mchar_test_a\\000950.png', '30'],
#  ['./tcdata/mchar_test_a\\000951.png', '19'],
#  ['./tcdata/mchar_test_a\\000952.png', '348'],
#  ['./tcdata/mchar_test_a\\000953.png', '85'],
#  ['./tcdata/mchar_test_a\\000954.png', '237'],
#  ['./tcdata/mchar_test_a\\000955.png', '253'],
#  ['./tcdata/mchar_test_a\\000956.png', '376'],
#  ['./tcdata/mchar_test_a\\000957.png', '26'],
#  ['./tcdata/mchar_test_a\\000958.png', '1538'],
#  ['./tcdata/mchar_test_a\\000959.png', '76'],
#  ['./tcdata/mchar_test_a\\000960.png', '170'],
#  ['./tcdata/mchar_test_a\\000961.png', '54'],
#  ['./tcdata/mchar_test_a\\000962.png', '130'],
#  ['./tcdata/mchar_test_a\\000963.png', '154'],
#  ['./tcdata/mchar_test_a\\000964.png', '108'],
#  ['./tcdata/mchar_test_a\\000965.png', '42'],
#  ['./tcdata/mchar_test_a\\000966.png', '371'],
#  ['./tcdata/mchar_test_a\\000967.png', '590'],
#  ['./tcdata/mchar_test_a\\000968.png', '46'],
#  ['./tcdata/mchar_test_a\\000969.png', '311'],
#  ['./tcdata/mchar_test_a\\000970.png', '72'],
#  ['./tcdata/mchar_test_a\\000971.png', '353'],
#  ['./tcdata/mchar_test_a\\000972.png', '117'],
#  ['./tcdata/mchar_test_a\\000973.png', '26'],
#  ['./tcdata/mchar_test_a\\000974.png', '862'],
#  ['./tcdata/mchar_test_a\\000975.png', '301'],
#  ['./tcdata/mchar_test_a\\000976.png', '35'],
#  ['./tcdata/mchar_test_a\\000977.png', '28'],
#  ['./tcdata/mchar_test_a\\000978.png', '8'],
#  ['./tcdata/mchar_test_a\\000979.png', '44'],
#  ['./tcdata/mchar_test_a\\000980.png', '139'],
#  ['./tcdata/mchar_test_a\\000981.png', '768'],
#  ['./tcdata/mchar_test_a\\000982.png', '275'],
#  ['./tcdata/mchar_test_a\\000983.png', '30'],
#  ['./tcdata/mchar_test_a\\000984.png', '390'],
#  ['./tcdata/mchar_test_a\\000985.png', '60'],
#  ['./tcdata/mchar_test_a\\000986.png', '12'],
#  ['./tcdata/mchar_test_a\\000987.png', '2'],
#  ['./tcdata/mchar_test_a\\000988.png', '169'],
#  ['./tcdata/mchar_test_a\\000989.png', '97'],
#  ['./tcdata/mchar_test_a\\000990.png', '24'],
#  ['./tcdata/mchar_test_a\\000991.png', '601'],
#  ['./tcdata/mchar_test_a\\000992.png', '21'],
#  ['./tcdata/mchar_test_a\\000993.png', '187'],
#  ['./tcdata/mchar_test_a\\000994.png', '286'],
#  ['./tcdata/mchar_test_a\\000995.png', '119'],
#  ['./tcdata/mchar_test_a\\000996.png', '84'],
#  ['./tcdata/mchar_test_a\\000997.png', '2'],
#  ['./tcdata/mchar_test_a\\000998.png', '131'],
#  ['./tcdata/mchar_test_a\\000999.png', '257'],
#  ...]

# %% [markdown]
# ## 模型融合

# %%
def stack_eval(mb_path,res_path):
    mb_net = DigitsMobileNet().cuda()
    mb_net.load_state_dict(torch.load(mb_path)['model'])

    res_net = DigitsResNet101().cuda()
    res_net.load_state_dict(torch.load(res_path)['model'])

    mb_net.eval()
    res_net.eval()

    dataset = DigitsDataset(mode='val',aug=False)

    val_loader = DataLoader(dataset, batch_size=config.batch_size, shuffle=False, num_workers=8,pin_memory=True, drop_last=False)
    corrects = 0

    with torch.no_grad():  # 关闭梯度计算
        tbar = tqdm(val_loader)
        for i, (img, label) in enumerate(tbar):
            img, label = img.cuda(), label.cuda()
            pred = [0.4*a+0.6*b for a, b in zip(mb_net(img), res_net(img))] # 对预测结果加权平均求和



            temp = torch.stack([
                pred[0].argmax(1) == label[:, 0], \
                pred[1].argmax(1) == label[:, 1], \
                pred[2].argmax(1) == label[:, 2], \
                pred[3].argmax(1) == label[:, 3], \
                ], dim=1)

            corrects += torch.all(temp, dim=1).sum().item()
            tbar.set_description('Val Acc: %.2f' % (corrects * 100 / ((i + 1) * config.batch_size)))
    res_net.train()  # 切换为训练模式
    mb_net.train()
    return corrects / (len(val_loader) * config.batch_size)

# resnet101和mobilenet融合
def stack_predict(mb_path,res_path):
    test_loader = DataLoader(DigitsDataset(mode='test'), batch_size=config.batch_size, shuffle=False, num_workers=8,pin_memory=True, drop_last=False)

    results = []

    mb_net = DigitsMobileNet().cuda()
    mb_net.load_state_dict(torch.load(mb_path)['model'])

    res_net = DigitsResNet101().cuda()
    res_net.load_state_dict(torch.load(res_path)['model'])

    mb_net.eval()
    res_net.eval()

    tbar = tqdm(test_loader)
    with torch.no_grad():
        for i, (img, label) in enumerate(tbar):
            img = img.cuda()
            pred = [0.4*a+0.6*b for a, b in zip(mb_net(img), res_net(img))]
            results += [[name, code] for name, code in zip(label, parse2class(pred))]


    results = sorted(results,key=lambda x: x[0])

    write2csv_stack(results)
    return results


def write2csv_stack(results):
    #定义输出文件
    df = pd.DataFrame(results, columns=['file_name', 'file_code'])
    df['file_name'] = df['file_name'].apply(lambda x: x.split('\\')[-1])
    save_name = './prediction_result/results-stack-res101_mb.csv'
    df.to_csv(save_name, sep=',', index=None)
    print('Results.saved to %s' % save_name)

# %%
# stack_eval('./user_data/model_data/checkpoints/epoch-mobilenet-33-bn-acc-73.56.pth','./user_data/model_data/checkpoints/epoch-DigitsResnet101-47-bn-acc-76.16.pth')

# %%
stack_predict('./user_data/model_data/checkpoints/epoch-mobilenet-33-bn-acc-73.56.pth','./user_data/model_data/checkpoints/epoch-DigitsResnet101-47-bn-acc-76.16.pth')
torch.cuda.empty_cache()
# Out:
#   0%|          | 0/625 [00:41<?, ?it/s]
# Results.saved to ./prediction_result/results-stack-res101+mb.csv
